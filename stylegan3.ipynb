# %%
# !python /kaggle/input/stylegan3/pytorch/default/1/stylegan3/gen_images.py --outdir=out/video.mp4 --trunc=0.7 --seeds=85 --network=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-t-ffhq-1024x1024.pkl
# Out:
# Loading networks from "https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-t-ffhq-1024x1024.pkl"...
# ...

# %% [raw]
# !ls
